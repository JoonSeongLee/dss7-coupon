# %% [markdown]
# ## Prefecture_locations
#
# : 현 위치별 위도, 경도

# %%
from ml_config import *

# %% [markdown]
# ### 1. Data Load

# %%
prefecture_locations = pd.read_csv('../data/prefecture_locations.csv')
prefecture_locations.tail()
# Out:
#                PREF_NAME PREFECTUAL_OFFICE   LATITUDE   LONGITUDE
# 42   Kumamoto Prefecture          Kumamoto  32.789828  130.741667
# 43       Oita Prefecture              Oita  33.238194  131.612591
# 44   Miyazaki Prefecture          Miyazaki  31.911090  131.423855
# 45  Kagoshima prefecture         Kagoshima  31.560148  130.557981
# 46               Okinawa              Naha  26.212401  127.680932

# %% [markdown]
# ### 2. Overall EDA

# %%
prefecture_locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 4 columns):
# PREF_NAME            47 non-null object
# PREFECTUAL_OFFICE    47 non-null object
# LATITUDE             47 non-null float64
# LONGITUDE            47 non-null float64
# dtypes: float64(2), object(2)
# memory usage: 1.5+ KB

# %%
for i in range(0, len(prefecture_locations.columns)):
    print('{} : {}'.format(prefecture_locations.columns[i], len(set(prefecture_locations[prefecture_locations.columns[i]]))))
# Out:
# PREF_NAME : 47
# PREFECTUAL_OFFICE : 47
# LATITUDE : 47
# LONGITUDE : 47

# %% [markdown]
# ### 3. Lacation

# %%
longitude = list(prefecture_locations['LONGITUDE'])
latitude = list(prefecture_locations['LATITUDE'])
plt.figure(figsize = (10, 8))
plt.plot(longitude, latitude, '.', alpha = 0.8, markersize = 15)
plt.show()
