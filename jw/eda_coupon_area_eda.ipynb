# %%
from ml_config import *

# %%
view = pd.read_csv('../data/coupon_visit_train.csv',memory_map=True,index_col=0)
purchase = pd.read_csv('../data/coupon_detail_train.csv',memory_map=True,index_col=0)

# %%
vp = pd.merge(view, purchase, on=['I_DATE', 'PURCHASEID_hash', 'USER_ID_hash'])

# %%
vp
# Out:
#                   I_DATE  PAGE_SERIAL                     REFERRER_hash  \
# 0    2012-06-16 16:38:23           10  878034ded0ee2297d7ce27c5169e8584
# 1    2012-06-03 18:03:38           31  878034ded0ee2297d7ce27c5169e8584
# 2    2012-06-04 19:38:33            6  878034ded0ee2297d7ce27c5169e8584
# 3    2012-03-05 23:47:09            9  878034ded0ee2297d7ce27c5169e8584
# 4    2011-09-22 18:59:59           36  6c5616ced18d79fa5a97c5c8f3e65f8f
# 5    2012-03-28 00:05:35           13  6c5616ced18d79fa5a97c5c8f3e65f8f
# 6    2011-07-11 12:02:48           13  6c5616ced18d79fa5a97c5c8f3e65f8f
# 7    2011-11-01 15:21:02           24  6c5616ced18d79fa5a97c5c8f3e65f8f
# 8    2012-06-04 15:25:24          169  878034ded0ee2297d7ce27c5169e8584
# 9    2012-06-04 20:18:06            8  878034ded0ee2297d7ce27c5169e8584
# 10   2012-06-06 20:39:30           20  878034ded0ee2297d7ce27c5169e8584
# 11   2012-05-01 17:24:59           30  6c5616ced18d79fa5a97c5c8f3e65f8f
# ...

# %%
vc = set(view.columns)
pc = set(purchase.columns)
vpc = set(vp.columns)

# %%
vc
# Out:
# {'I_DATE',
#  'PAGE_SERIAL',
#  'PURCHASEID_hash',
#  'REFERRER_hash',
#  'SESSION_ID_hash',
#  'USER_ID_hash',
#  'VIEW_COUPON_ID_hash'}

# %%
pc
# Out:
# {'COUPON_ID_hash',
#  'ITEM_COUNT',
#  'I_DATE',
#  'PURCHASEID_hash',
#  'SMALL_AREA_NAME',
#  'USER_ID_hash'}

# %%
vc.intersection(pc)
# Out:
# {'I_DATE', 'PURCHASEID_hash', 'USER_ID_hash'}

# %%
vpc
# Out:
# {'COUPON_ID_hash',
#  'ITEM_COUNT',
#  'I_DATE',
#  'PAGE_SERIAL',
#  'PURCHASEID_hash',
#  'REFERRER_hash',
#  'SESSION_ID_hash',
#  'SMALL_AREA_NAME',
#  'USER_ID_hash',
#  'VIEW_COUPON_ID_hash'}

# %%
len(view), len(purchase), len(vp)
# Out:
# (2833180, 168996, 276)

# %%
len(pd.unique(view['USER_ID_hash']))
# Out:
# 22805

# %%
len(pd.unique(purchase['USER_ID_hash']))
# Out:
# 22782

# %%
pref = pd.read_csv('../data/prefecture_locations.csv',memory_map=True,index_col=0)

# %%
pref.head()
# Out:
#            PREF_NAME PREFECTUAL_OFFICE   LATITUDE   LONGITUDE
# 0           Hokkaido           Sapporo  43.063968  141.347899
# 1  Aomori Prefecture            Aomori  40.824623  140.740593
# 2   Iwate Prefecture           Morioka  39.703531  141.152667
# 3  Miyagi Prefecture            Sendai  38.268839  140.872103
# 4              Akita             Akita  39.718600  140.102334

# %%
coupon = pd.read_csv('../data/coupon_list_train.csv',memory_map=True,index_col=0)

# %%
coupon.head()
# Out:
#   CAPSULE_TEXT GENRE_NAME  PRICE_RATE  CATALOG_PRICE  DISCOUNT_PRICE  \
# 0         Food       Food          50           3000            1500
# 1         Food       Food          51           2080            1000
# 2         Food       Food          50           7000            3500
# 3         Food       Food          50           3000            1500
# 4         Food       Food          50           2000            1000
#
#               DISPFROM              DISPEND  DISPPERIOD   VALIDFROM  \
# 0  2011-07-08 12:00:00  2011-07-09 12:00:00           1  2011-07-10
# 1  2011-07-01 12:00:00  2011-07-02 12:00:00           1  2011-07-03
# 2  2011-07-12 12:00:00  2011-07-15 12:00:00           3  2011-07-16
# 3  2011-07-09 12:00:00  2011-07-11 12:00:00           2  2011-07-12
# 4  2011-07-05 12:00:00  2011-07-06 12:00:00           1  2011-07-07
#
#      VALIDEND                ...                 USABLE_DATE_THU  \
# 0  2011-12-08                ...                             1.0
# ...

# %%
cp = set(coupon['ken_name'].unique())

# %%
pp = set(pref['PREF_NAME'].unique())

# %%
cp == pp
# Out:
# True

# %% [markdown]
# ### coupon_list의 prefecture와 prefecture_locations의 prefecture는 동일한 도메인을 가짐

# %%
coupon.head()
# Out:
#   CAPSULE_TEXT GENRE_NAME  PRICE_RATE  CATALOG_PRICE  DISCOUNT_PRICE  \
# 0         Food       Food          50           3000            1500
# 1         Food       Food          51           2080            1000
# 2         Food       Food          50           7000            3500
# 3         Food       Food          50           3000            1500
# 4         Food       Food          50           2000            1000
#
#               DISPFROM              DISPEND  DISPPERIOD   VALIDFROM  \
# 0  2011-07-08 12:00:00  2011-07-09 12:00:00           1  2011-07-10
# 1  2011-07-01 12:00:00  2011-07-02 12:00:00           1  2011-07-03
# 2  2011-07-12 12:00:00  2011-07-15 12:00:00           3  2011-07-16
# 3  2011-07-09 12:00:00  2011-07-11 12:00:00           2  2011-07-12
# 4  2011-07-05 12:00:00  2011-07-06 12:00:00           1  2011-07-07
#
#      VALIDEND                ...                 USABLE_DATE_THU  \
# 0  2011-12-08                ...                             1.0
# ...

# %%
len(pref)
# Out:
# 47

# %%
len(coupon['ken_name'].unique())
# Out:
# 47

# %%
clp = pd.merge(coupon,pref,left_on='ken_name',right_on='PREF_NAME')
# 쿠폰 리스트 + 위도 경도

# %%
len(clp)
# Out:
# 19413

# %%
clp
# Out:
#              CAPSULE_TEXT                GENRE_NAME  PRICE_RATE  \
# 0                    Food                      Food          50
# 1      Nail and eye salon        Nail and eye salon          50
# 2              Hair salon                Hair salon          66
# 3              Hair salon                Hair salon          66
# 4                     Spa                       Spa          50
# 5                     Spa                       Spa          81
# 6        Delivery service          Delivery service          50
# 7        Delivery service          Delivery service          50
# 8                    Food                      Food          50
# 9        Delivery service          Delivery service          50
# 10       Delivery service          Delivery service          50
# 11       Delivery service          Delivery service          67
# 12                   Food                      Food          50
# 13       Delivery service          Delivery service          50
# ...

# %%
area = pd.read_csv('../data/coupon_area_train.csv',memory_map=True,index_col=0)

# %%
coupon.head()
# Out:
#   CAPSULE_TEXT GENRE_NAME  PRICE_RATE  CATALOG_PRICE  DISCOUNT_PRICE  \
# 0         Food       Food          50           3000            1500
# 1         Food       Food          51           2080            1000
# 2         Food       Food          50           7000            3500
# 3         Food       Food          50           3000            1500
# 4         Food       Food          50           2000            1000
#
#               DISPFROM              DISPEND  DISPPERIOD   VALIDFROM  \
# 0  2011-07-08 12:00:00  2011-07-09 12:00:00           1  2011-07-10
# 1  2011-07-01 12:00:00  2011-07-02 12:00:00           1  2011-07-03
# 2  2011-07-12 12:00:00  2011-07-15 12:00:00           3  2011-07-16
# 3  2011-07-09 12:00:00  2011-07-11 12:00:00           2  2011-07-12
# 4  2011-07-05 12:00:00  2011-07-06 12:00:00           1  2011-07-07
#
#      VALIDEND                ...                 USABLE_DATE_THU  \
# 0  2011-12-08                ...                             1.0
# ...

# %%
len(coupon), len(coupon['COUPON_ID_hash'].unique())
# Out:
# (19413, 19413)

# %%
area.head()
# Out:
#   SMALL_AREA_NAME           PREF_NAME                    COUPON_ID_hash
# 0         Saitama  Saitama Prefecture  6b263844241eea98c5a97f1335ea82af
# 1           Chiba    Chiba Prefecture  cc031f250e8bad1e24060263b9fc0ddd
# 2           Chiba    Chiba Prefecture  ba5e9b7453ca52ff711635a5d2e8102d
# 3           Chiba    Chiba Prefecture  3e1ffbedca3569f9e8032d401e8cb4e6
# 4           Chiba    Chiba Prefecture  782934b6c815b4030ea204eef7d4a734

# %%
len(area), len(area['COUPON_ID_hash'].unique())
# Out:
# (138185, 19368)

# %%
area
# Out:
#                                   SMALL_AREA_NAME             PREF_NAME  \
# 0                                         Saitama    Saitama Prefecture
# 1                                           Chiba      Chiba Prefecture
# 2                                           Chiba      Chiba Prefecture
# 3                                           Chiba      Chiba Prefecture
# 4                                           Chiba      Chiba Prefecture
# 5                                           Chiba      Chiba Prefecture
# 6       Shinjuku, Takadanobaba Nakano - Kichijoji                 Tokyo
# 7                                           Kyoto                 Kyoto
# 8                         Ebisu, Meguro Shinagawa                 Tokyo
# 9                    Ginza Shinbashi, Tokyo, Ueno                 Tokyo
# 10                   Ginza Shinbashi, Tokyo, Ueno                 Tokyo
# 11                   Ginza Shinbashi, Tokyo, Ueno                 Tokyo
# ...

# %%
c1 = set(coupon['COUPON_ID_hash'].unique())
c2 = set(area['COUPON_ID_hash'].unique())

# %%
# coupon_list엔 있는데 area엔 없는 COUPON_ID들
c1-c2, len(c1-c2)
# Out:
# ({'0c581761df0e024a491b48fc2a3fe903',
#   '11a522c527109ccf10c2a84ffbf3c2b3',
#   '1264e574ea807ab28a0040fa87aed66f',
#   '1449e8072085b7e239be397376848c6e',
#   '156696f82d40dcbfcf2cd4e0bf64215d',
#   '182b9eea35c72a72768b6c05f2767983',
#   '1a53e9e5b7ee4b330167b1733098f9ed',
#   '1fbd109c022531bb864c7ea29e2f0c75',
#   '3459b6077c57b54228f052de0e18a71a',
#   '3473db88d34aed3075f37bafa5805b31',
#   '3f8906815eecafb9f979c8d047b6efe4',
#   '41269c405e36e18a780019b32e36c241',
#   '47da25aee3028f446ee02bcc7bcff6a2',
#   '4ed73bc58e3e54d42b114d8a42848db5',
#   '4ff369449f765e28faa070cfeafe509f',
#   '5de14312ea3b2ce8513358f5dfe1e6ed',
#   '6288bcaef3d7cbbfce5a5de2faf743ec',
#   '62ba19033a97780077ce5f4c21ac83ec',
#   '6c450443daaf0913b552781787e603eb',
#   '6db5488383a27f57f3c0bca28ca8f1fd',
#   '7eec23a114c488ecfe5666f781ec3bde',
#   '8046b0e08147727b2d1b4245467e37e4',
#   '87aa38c454f79a07407064c399b9f57b',
#   '87dffd3de21174c916c49bd31b6d885d',
#   '89acdbc66e45a891cbf3d3f133d8932d',
# ...

# %%
tmp = coupon[coupon['COUPON_ID_hash'].isin(c1-c2)]

# %%
tmp
# Out:
#              CAPSULE_TEXT                GENRE_NAME  PRICE_RATE  \
# 59                   Food                      Food          58
# 104                  Food                      Food          50
# 110                  Food                      Food          50
# 278    Nail and eye salon        Nail and eye salon          66
# 329            Relaxation                Relaxation          56
# 356                  Food                      Food          54
# 357                  Food                      Food          54
# 361                  Food                      Food          50
# 369            Relaxation                Relaxation          71
# 388                  Food                      Food          50
# 391                  Food                      Food          50
# 398                  Food                      Food          50
# 402             Gift card                 Gift card          50
# 404                  Food                      Food          50
# ...

# %%
coupon[coupon['COUPON_ID_hash']=='931fb8c3cd02f4e63ada44470e54bf14']
# Out:
#                 CAPSULE_TEXT GENRE_NAME  PRICE_RATE  CATALOG_PRICE  \
# 19395  Correspondence course     Lesson          66           8940
#
#        DISCOUNT_PRICE             DISPFROM              DISPEND  DISPPERIOD  \
# 19395            2980  2012-06-22 12:00:00  2012-06-25 12:00:00           3
#
#       VALIDFROM VALIDEND                ...                 USABLE_DATE_THU  \
# 19395       NaN      NaN                ...                             NaN
#
#        USABLE_DATE_FRI  USABLE_DATE_SAT  USABLE_DATE_SUN  USABLE_DATE_HOLIDAY  \
# 19395              NaN              NaN              NaN                  NaN
#
#        USABLE_DATE_BEFORE_HOLIDAY  large_area_name  ken_name  \
# 19395                         NaN            Kanto     Tokyo
#
#                     small_area_name                    COUPON_ID_hash
# 19395  Ginza Shinbashi, Tokyo, Ueno  931fb8c3cd02f4e63ada44470e54bf14
#
# [1 rows x 24 columns]

# %%
len(area['SMALL_AREA_NAME'].unique())
# Out:
# 55

# %%
len(area['PREF_NAME'].unique())
# Out:
# 47

# %%
len(coupon['small_area_name'].unique())
# Out:
# 55

# %%
len(coupon['ken_name'].unique())
# Out:
# 47

# %%
len(coupon)
# Out:
# 19413

# %%
t_area = pd.read_csv('../data/coupon_area_test.csv',memory_map=True,index_col=0)

# %%
tmp = set(t_area['COUPON_ID_hash'].unique())

# %%
tmp
# Out:
# {'007dce05be7f473f362e79bfe7256736',
#  '00fcc93438a282f8b915777a209dd0bd',
#  '01023eac71c13f529f43cfb691d914c9',
#  '0147fd072c6ef4e299d428f19a5f0e01',
#  '017956f30c352df708358a6d1219fb12',
#  '01f995ae8c168d5eb7b0fd69cf8ee6b2',
#  '03876bc74d321132f40d2ad6c8c420f9',
#  '059a13d7779c38f345a132280caa05ed',
#  '05c58bb36b58b4928c6b0a46a0cedfeb',
#  '06696e5b4afee54a10cc1c0637a83913',
#  '0855a38feec9156f8849b7b89eaccdec',
#  '0871d5de805bf7f26fca485d24ec65e9',
#  '09ac6e78e77fabbcec070e8427c258a8',
#  '09aeb1dad89febf028823923f99fc9bd',
#  '09ec991661af3ac7bc3b5cddc31e2fa0',
#  '0a202a8b338ded7a5583076483dd02e3',
#  '0acc89ba7593ed787e3439b7f05884c2',
#  '0c015306597566b632bebfb63b7e59f3',
#  '0d0df1856bda22a56bc6e5a7c92ac88a',
#  '0da4709d065835039f700d9bb67b461b',
#  '0e37c4527014d9ecee7fe41cc49560fb',
#  '0e917a0e872246a36e7a9a28df505562',
#  '0ed660499be5fdca5c8c7242c656a9d1',
#  '0fb2dab415369349676dc3d3e3fba003',
#  '0fd38be174187a3de72015ce9d5ca3a2',
# ...

# %%
len(tmp - (c1-c2))
# Out:
# 310

# %%
area.head()
# Out:
#   SMALL_AREA_NAME           PREF_NAME                    COUPON_ID_hash
# 0         Saitama  Saitama Prefecture  6b263844241eea98c5a97f1335ea82af
# 1           Chiba    Chiba Prefecture  cc031f250e8bad1e24060263b9fc0ddd
# 2           Chiba    Chiba Prefecture  ba5e9b7453ca52ff711635a5d2e8102d
# 3           Chiba    Chiba Prefecture  3e1ffbedca3569f9e8032d401e8cb4e6
# 4           Chiba    Chiba Prefecture  782934b6c815b4030ea204eef7d4a734

# %%
len(area)
# Out:
# 138185

# %%
sns.set(font_scale=2)
plt.figure(figsize=(20, 30))
sns.countplot(y = 'PREF_NAME', data=area, order=area['PREF_NAME'].value_counts().index)

# %%
area['PREF_NAME'].value_counts()
# Out:
# Tokyo                   19720
# Osaka prefecture         6942
# Kanagawa Prefecture      6152
# Aichi Prefecture         3275
# Fukuoka Prefecture       3135
# Saitama Prefecture       3035
# Hyogo Prefecture         3027
# Chiba Prefecture         2922
# Hokkaido                 2715
# Kyoto                    2697
# Shizuoka Prefecture      2692
# Gifu Prefecture          2682
# Hiroshima Prefecture     2664
# Okayama Prefecture       2558
# Mie                      2527
# Yamanashi Prefecture     2466
# Nagano Prefecture        2388
# Miyagi Prefecture        2374
# Tochigi Prefecture       2368
# Niigata Prefecture       2364
# Kagawa Prefecture        2357
# Nara Prefecture          2347
# Gunma Prefecture         2335
# Saga Prefecture          2335
# Ishikawa Prefecture      2329
# Ibaraki Prefecture       2316
# Tokushima Prefecture     2282
# Nagasaki Prefecture      2270
# Aomori Prefecture        2264
# Ehime Prefecture         2254
# Akita                    2248
# ...

# %%
19720 / 138185
# Out:
# 0.14270724029380902

# %% [markdown]
# # Tokyo가 제일 많은 비중을 차지
# # coupon_list_eda와의 area 컬럼들과 경향이 비슷

# %%
sns.set(font_scale=2)
plt.figure(figsize=(20, 30))
sns.countplot(y='ken_name', data=coupon, order=coupon['ken_name'].value_counts().index)

# %%
coupon['ken_name'].value_counts().index
# Out:
# Index(['Tokyo', 'Osaka prefecture', 'Kanagawa Prefecture', 'Aichi Prefecture',
#        'Hyogo Prefecture', 'Hokkaido', 'Fukuoka Prefecture',
#        'Saitama Prefecture', 'Shizuoka Prefecture', 'Chiba Prefecture',
#        'Kyoto', 'Nagano Prefecture', 'Miyagi Prefecture', 'Okinawa',
#        'Hiroshima Prefecture', 'Okayama Prefecture', 'Gifu Prefecture', 'Mie',
#        'Oita Prefecture', 'Tochigi Prefecture', 'Nagasaki Prefecture',
#        'Niigata Prefecture', 'Kumamoto Prefecture', 'Gunma Prefecture',
#        'Yamanashi Prefecture', 'Fukushima Prefecture', 'Kagoshima prefecture',
#        'Ehime Prefecture', 'Ishikawa Prefecture', 'Nara Prefecture',
#        'Miyazaki Prefecture', 'Saga Prefecture', 'Iwate Prefecture',
#        'Kagawa Prefecture', 'Yamagata Prefecture', 'Shiga Prefecture',
#        'Yamaguchi Prefecture', 'Toyama Prefecture', 'Fukui Prefecture',
#        'Aomori Prefecture', 'Wakayama Prefecture', 'Shimane Prefecture',
# ...

# %%
area['PREF_NAME'].value_counts().index
# Out:
# Index(['Tokyo', 'Osaka prefecture', 'Kanagawa Prefecture', 'Aichi Prefecture',
#        'Fukuoka Prefecture', 'Saitama Prefecture', 'Hyogo Prefecture',
#        'Chiba Prefecture', 'Hokkaido', 'Kyoto', 'Shizuoka Prefecture',
#        'Gifu Prefecture', 'Hiroshima Prefecture', 'Okayama Prefecture', 'Mie',
#        'Yamanashi Prefecture', 'Nagano Prefecture', 'Miyagi Prefecture',
#        'Tochigi Prefecture', 'Niigata Prefecture', 'Kagawa Prefecture',
#        'Nara Prefecture', 'Gunma Prefecture', 'Saga Prefecture',
#        'Ishikawa Prefecture', 'Ibaraki Prefecture', 'Tokushima Prefecture',
#        'Nagasaki Prefecture', 'Aomori Prefecture', 'Ehime Prefecture', 'Akita',
#        'Fukushima Prefecture', 'Shiga Prefecture', 'Tottori Prefecture',
#        'Wakayama Prefecture', 'Yamagata Prefecture', 'Toyama Prefecture',
#        'Iwate Prefecture', 'Yamaguchi Prefecture', 'Oita Prefecture',
#        'Fukui Prefecture', 'Kochi Prefecture', 'Kumamoto Prefecture',
# ...

# %%
import gen as g

# %%
tmp = g.coupon_pref()

# %%
tmp
# Out:
#              CAPSULE_TEXT                GENRE_NAME  PRICE_RATE  \
# 0                    Food                      Food          50
# 1      Nail and eye salon        Nail and eye salon          50
# 2              Hair salon                Hair salon          66
# 3              Hair salon                Hair salon          66
# 4                     Spa                       Spa          50
# 5                     Spa                       Spa          81
# 6        Delivery service          Delivery service          50
# 7        Delivery service          Delivery service          50
# 8                    Food                      Food          50
# 9        Delivery service          Delivery service          50
# 10       Delivery service          Delivery service          50
# 11       Delivery service          Delivery service          67
# 12                   Food                      Food          50
# 13       Delivery service          Delivery service          50
# ...

# %%
g.area()
# Out:
#                                   SMALL_AREA_NAME             PREF_NAME  \
# 0                                         Saitama    Saitama Prefecture
# 1                                           Chiba      Chiba Prefecture
# 2                                           Chiba      Chiba Prefecture
# 3                                           Chiba      Chiba Prefecture
# 4                                           Chiba      Chiba Prefecture
# 5                                           Chiba      Chiba Prefecture
# 6       Shinjuku, Takadanobaba Nakano - Kichijoji                 Tokyo
# 7                                           Kyoto                 Kyoto
# 8                         Ebisu, Meguro Shinagawa                 Tokyo
# 9                    Ginza Shinbashi, Tokyo, Ueno                 Tokyo
# 10                   Ginza Shinbashi, Tokyo, Ueno                 Tokyo
# 11                   Ginza Shinbashi, Tokyo, Ueno                 Tokyo
# ...

# %%
pd.merge(tmp, g.area(), left_on=['COUPON_ID_hash','PREF_NAME','small_area_name'], right_on=['COUPON_ID_hash','PREF_NAME','SMALL_AREA_NAME'])
# Out:
#              CAPSULE_TEXT                GENRE_NAME  PRICE_RATE  \
# 0                    Food                      Food          50
# 1      Nail and eye salon        Nail and eye salon          50
# 2              Hair salon                Hair salon          66
# 3              Hair salon                Hair salon          66
# 4                     Spa                       Spa          50
# 5                     Spa                       Spa          81
# 6        Delivery service          Delivery service          50
# 7                    Food                      Food          50
# 8        Delivery service          Delivery service          50
# 9        Delivery service          Delivery service          50
# 10       Delivery service          Delivery service          67
# 11                   Food                      Food          50
# 12       Delivery service          Delivery service          50
# 13       Delivery service          Delivery service          50
# ...

# %%
tmp.merge(g.area())
# Out:
#              CAPSULE_TEXT                GENRE_NAME  PRICE_RATE  \
# 0                    Food                      Food          50
# 1      Nail and eye salon        Nail and eye salon          50
# 2              Hair salon                Hair salon          66
# 3              Hair salon                Hair salon          66
# 4                     Spa                       Spa          50
# 5                     Spa                       Spa          81
# 6        Delivery service          Delivery service          50
# 7                    Food                      Food          50
# 8        Delivery service          Delivery service          50
# 9        Delivery service          Delivery service          50
# 10       Delivery service          Delivery service          67
# 11                   Food                      Food          50
# 12       Delivery service          Delivery service          50
# 13       Delivery service          Delivery service          50
# ...
